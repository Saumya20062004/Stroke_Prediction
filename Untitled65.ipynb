# %% [markdown]
# <a href="https://colab.research.google.com/github/Saumya20062004/Saumya-Tevatia/blob/main/Untitled65.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/healthcare-dataset-stroke-data.csv')
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df['heart_disease'].value_counts().plot(kind="bar",color = "red")
# Out:
# <Axes: >

# %%
df['work_type'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='work_type'>

# %%
df['gender'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='gender'>

# %%
df['hypertension'].value_counts().plot(kind="bar",color = "blue")
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=5110, step=1),
#  Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#         'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#         'smoking_status', 'stroke'],
#        dtype='object')]

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
print(df.isna().sum())
df.isna().sum().plot.barh()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64
# <Axes: >

# %%
mean_bmi = df['bmi'].mean()

# %%
pf=df['bmi'].fillna(mean_bmi, inplace=True)
pf

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
xya=df.drop(df.columns[0:8],axis=1)
xya
# Out:
#       avg_glucose_level        bmi   smoking_status  stroke
# 0                228.69  36.600000  formerly smoked       1
# 1                202.21  28.893237     never smoked       1
# 2                105.92  32.500000     never smoked       1
# 3                171.23  34.400000           smokes       1
# 4                174.12  24.000000     never smoked       1
# ...                 ...        ...              ...     ...
# 5105              83.75  28.893237     never smoked       0
# 5106             125.20  40.000000     never smoked       0
# 5107              82.99  30.600000     never smoked       0
# 5108             166.29  25.600000  formerly smoked       0
# 5109              85.28  26.200000          Unknown       0
#
# [5110 rows x 4 columns]

# %%
xz = xya.drop('smoking_status', axis=1)
xz
# Out:
#       avg_glucose_level        bmi  stroke
# 0                228.69  36.600000       1
# 1                202.21  28.893237       1
# 2                105.92  32.500000       1
# 3                171.23  34.400000       1
# 4                174.12  24.000000       1
# ...                 ...        ...     ...
# 5105              83.75  28.893237       0
# 5106             125.20  40.000000       0
# 5107              82.99  30.600000       0
# 5108             166.29  25.600000       0
# 5109              85.28  26.200000       0
#
# [5110 rows x 3 columns]

# %%
xy = xya[['stroke', 'bmi']]
xy
# Out:
#       stroke        bmi
# 0          1  36.600000
# 1          1  28.893237
# 2          1  32.500000
# 3          1  34.400000
# 4          1  24.000000
# ...      ...        ...
# 5105       0  28.893237
# 5106       0  40.000000
# 5107       0  30.600000
# 5108       0  25.600000
# 5109       0  26.200000
#
# [5110 rows x 2 columns]

# %%
plt.scatter(xy.bmi,xy.stroke,marker='*',color='blue')

# %%
y=xy.drop('bmi',axis='columns')
y
# Out:
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 1 columns]

# %%
x=xy.drop('stroke',axis='columns')
x
# Out:
#             bmi
# 0     36.600000
# 1     28.893237
# 2     32.500000
# 3     34.400000
# 4     24.000000
# ...         ...
# 5105  28.893237
# 5106  40.000000
# 5107  30.600000
# 5108  25.600000
# 5109  26.200000
#
# [5110 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y ,test_size=0.2, random_state=0)

# %%
x_train
# Out:
#        bmi
# 3029  36.7
# 2277  48.5
# 3002  30.8
# 246   29.3
# 2825  25.6
# ...    ...
# 4931  38.8
# 3264  26.0
# 1653  28.4
# 2607  29.7
# 2732  33.2
#
# [4088 rows x 1 columns]

# %%
y_train
# Out:
#       stroke
# 3029       0
# 2277       0
# 3002       0
# 246        1
# 2825       0
# ...      ...
# 4931       0
# 3264       0
# 1653       0
# 2607       0
# 2732       0
#
# [4088 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_predicted=model.predict(x_test)
y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model.predict_proba(x_test)
# Out:
# array([[0.95448485, 0.04551515],
#        [0.96095273, 0.03904727],
#        [0.95484186, 0.04515814],
#        ...,
#        [0.94692183, 0.05307817],
#        [0.95266414, 0.04733586],
#        [0.95898785, 0.04101215]])

# %%
x_test['Predicted y']=y_predicted
x_test
# Out:
#             bmi  Predicted y
# 42    26.400000            0
# 380   16.700000            0
# 3524  25.900000            0
# 352   34.100000            0
# 4927  13.700000            0
# ...         ...          ...
# 472   22.900000            0
# 4446  27.900000            0
# 660   36.200000            0
# 57    28.893237            0
# 2367  19.800000            0
#
# [1022 rows x 2 columns]

# %%
x_test['Actual y_test']=y_test
x_test
# Out:
#             bmi  Predicted y  Actual y_test
# 42    26.400000            0              1
# 380   16.700000            0              0
# 3524  25.900000            0              0
# 352   34.100000            0              0
# 4927  13.700000            0              0
# ...         ...          ...            ...
# 472   22.900000            0              0
# 4446  27.900000            0              0
# 660   36.200000            0              0
# 57    28.893237            0              1
# 2367  19.800000            0              0
#
# [1022 rows x 3 columns]

# %%
model.coef_
# Out:
# array([[0.01649751]])

# %%
model.intercept_
# Out:
# array([-3.47866079])

# %%
import math
def sigmoid(x):
  return 1/(1 + math.exp(-x))

# %%
def prediction_function(bmi):
  z= 0.016 * bmi - 3.478
  y=sigmoid(z)
  return y

# %%
bmi = 28
prediction_function(bmi)
# Out:
# 0.04608882703727964

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_predicted)
print(f'Accuracy Score: {accuracy}')
# Out:
# Accuracy Score: 0.9471624266144814
